# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# given parameters
diameter = 1.5 # in

E_al = 10e6 # psi
v_al = 0.34 # n.d.
t_al = 0.125 # in

E_comp = 1.92e6 # psi
v_comp = 0.51 # n.d.
t_comp = 0.075 # in

# %%
# calculate r_o and r_i
r_o = 0.5*diameter
r_i_al = r_o - t_al
r_i_comp = r_o - t_comp

# %%
# import data from csv
lab03data = naca0012 = pd.read_csv('Lab_3_Raw_Data.csv', header=None, skiprows=2)  
lab03data_df = pd.DataFrame(lab03data)

# %%
# store relevant data as numpy arrays
# ey (ch 2)
ey_al_bend_123 = np.asarray(lab03data_df[2][0:], dtype=float)
ey_al_bend_456 = np.asarray(lab03data_df[7][0:], dtype=float)

ey_al_torsion_123 = np.asarray(lab03data_df[12][0:], dtype=float)
ey_al_torsion_456 = np.asarray(lab03data_df[17][0:], dtype=float)

ey_comp_bend_123 = np.asarray(lab03data_df[22][0:], dtype=float)
ey_comp_bend_456 = np.asarray(lab03data_df[27][0:], dtype=float)

ey_comp_torsion_123 = np.asarray(lab03data_df[32][0:], dtype=float)
ey_comp_torsion_456 = np.asarray(lab03data_df[37][0:], dtype=float)

# ex (calculated)
ex_al_bend_123 = np.asarray(lab03data_df[4][0:], dtype=float)
ex_al_bend_456 = np.asarray(lab03data_df[9][0:], dtype=float)

ex_al_torsion_123 = np.asarray(lab03data_df[14][0:], dtype=float)
ex_al_torsion_456 = np.asarray(lab03data_df[19][0:], dtype=float)

ex_comp_bend_123 = np.asarray(lab03data_df[24][0:], dtype=float)
ex_comp_bend_456 = np.asarray(lab03data_df[29][0:], dtype=float)

ex_comp_torsion_123 = np.asarray(lab03data_df[34][0:], dtype=float)
ex_comp_torsion_456 = np.asarray(lab03data_df[39][0:], dtype=float)

# gamma_xy
gamma_al_bend_123 = np.asarray(lab03data_df[5][0:], dtype=float)
gamma_al_bend_456 = np.asarray(lab03data_df[10][0:], dtype=float)

gamma_al_torsion_123 = np.asarray(lab03data_df[15][0:], dtype=float)
gamma_al_torsion_456 = np.asarray(lab03data_df[20][0:], dtype=float)

gamma_comp_bend_123 = np.asarray(lab03data_df[25][0:], dtype=float)
gamma_comp_bend_456 = np.asarray(lab03data_df[30][0:], dtype=float)

gamma_comp_torsion_123 = np.asarray(lab03data_df[35][0:], dtype=float)
gamma_comp_torsion_456 = np.asarray(lab03data_df[40][0:], dtype=float)

# %%
# plot ex vs ey
fig = plt.figure(figsize=(12,8), tight_layout=True)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.plot(ex_al_bend_123, ey_al_bend_123, 'D--', color='tab:blue', label=r'Bending (Ch 123)')
ax1.plot(ex_al_bend_456, ey_al_bend_456, 'D--', color='tab:green', label=r'Bending (Ch 456)')
ax1.plot(ex_al_torsion_123, ey_al_torsion_123, 'D--', color='tab:red', label=r'Torsion (Ch 123)')
ax1.plot(ex_al_torsion_456, ey_al_torsion_456, 'D--', color='tab:orange', label=r'Torsion (Ch 456)')

ax2.plot(ex_comp_bend_123, ey_comp_bend_123, 'D--', color='tab:blue', label=r'Bending (Ch 123)')
ax2.plot(ex_comp_bend_456, ey_comp_bend_456, 'D--', color='tab:green', label=r'Bending (Ch 456)')
ax2.plot(ex_comp_torsion_123, ey_comp_torsion_123, 'D--', color='tab:red', label=r'Torsion (Ch 123)')
ax2.plot(ex_comp_torsion_456, ey_comp_torsion_456, 'D--', color='tab:orange', label=r'Torsion (Ch 456)')

ax1.set_xlabel( r'$\epsilon_x$ [$\mu$in/in]',fontsize=14)
ax1.set_ylabel( r'$\epsilon_y$ [$\mu$in/in]',fontsize=14)

ax2.set_xlabel( r'$\epsilon_x$ [$\mu$in/in]',fontsize=14)

ax1.legend(fontsize=14)
ax2.legend(fontsize=14)

plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('exvsey.png')

# %%
# plot Cd vs alpha
fig = plt.figure(figsize=(6,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(alpha_0012, Cd_0012, '-', color='tab:blue', label=r'NACA 0012')
ax1.plot(alpha_4412, Cd_4412, '-', color='tab:orange', label=r'NACA 4412')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Section Drag Coefficient, $C_d$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CdvsAlpha_1.png')

# %%
# plot Cl vs Cd
fig = plt.figure(figsize=(8,6), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(Cd_0012, Cl_0012, '-', color='tab:blue', label=r'NACA 0012')
ax1.plot(Cd_4412, Cl_4412, '-', color='tab:orange', label=r'NACA 4412')
ax1.set_xlabel( r'Section Drag Coefficient, $C_d$ [n.d.]',fontsize=14)
ax1.set_ylabel( r'Section Lift Coefficient, $C_l$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('ClvsCd_1.png')

# %% [markdown]
# # Linear interpolation to determine $\alpha_0$ for NACA 4412
# $\frac{y-y_0}{x-x_0}=\frac{y_1-y_0}{x_1-x_0}$

# %%
a0_4412 = (alpha_4412[2] - alpha_4412[1])/(Cl_4412[2] - Cl_4412[1])*(0 - Cl_4412[1])+alpha_4412[1]
a0_4412

# %% [markdown]
# # Determine $C_{l max}$

# %%
print(np.amax(Cl_0012), alpha_0012[np.argmax(Cl_0012)])
print(np.amax(Cl_4412), alpha_4412[np.argmax(Cl_4412)])

# %% [markdown]
# # Interpolate to determine zero-moment alpha (Q3.2)

# %%
cm1 = 0.001009
cm0 = -0.001040
alpha1 = 1.5
alpha0 = 2

(alpha1 - alpha0)/(cm1 - cm0) * (0 - cm0) + alpha0

# %%
# plot CM vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(alpha_35k, Cm_35k, '-', color='tab:green', label=r'$Re$ = 35,000')
ax1.plot(alpha_85k, Cm_85k, '-', color='tab:purple', label=r'$Re$ = 85,000')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Moment Coefficient, $C_M$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CMvsAlpha_sim.png')

# %%
# plot CL vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), CL_40, 'bo--', label=r'$Re$ = 35,000')
ax1.plot(np.degrees(alpha_100), CL_100, 'o--', color='tab:orange', label=r'$Re$ = 85,000')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Lift Coefficient, $C_L$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CLvsAlpha.png')

# %%
# plot CD vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), CD_40, 'bo--', label=r'$Re$ = 35,000')
ax1.plot(np.degrees(alpha_100), CD_100, 'o--', color='tab:orange', label=r'$Re$ = 85,000')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Drag Coefficient, $C_D$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CDvsAlpha.png')

# %%
# plot CM vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), CM_40, 'bo--', label=r'$Re$ = 35,000')
ax1.plot(np.degrees(alpha_100), CM_100, 'o--', color='tab:orange', label=r'$Re$ = 85,000')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Moment Coefficient, $C_M$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CMvsAlpha.png')

# %%
# plot L/D vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), LD_ratio_40, 'bo--', label=r'$Re$ = 35,000')
ax1.plot(np.degrees(alpha_100), LD_ratio_100, 'o--', color='tab:orange', label=r'$Re$ = 85,000')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Lift-Drag Ratio, L/D [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('LDvsAlpha.png')

# %%
# plot Drag Polar
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(CD_40, CL_40, 'bo--', label=r'$Re$ = 35,000')
ax1.plot(CD_100, CL_100, 'o--', color='tab:orange', label=r'$Re$ = 85,000')
ax1.set_xlabel( r'Drag Coefficient, $C_D$ [n.d.]',fontsize=14)
ax1.set_ylabel( r'Lift Coefficient, $C_L$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('DragPolar.png')

# %% [markdown]
# # Comparison Plots bw experimental and simulated data

# %%
# plot CL vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), CL_40, 'bo--', label=r'Experimental')
ax1.plot(alpha_35k, CL_35k, '-', color='tab:green', label=r'Simulated')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Lift Coefficient, $C_L$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CLvsAlpha_comp35k.png')

# %%
# plot CD vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), CD_40, 'bo--', label=r'Experimental')
ax1.plot(alpha_35k, CD_35k, '-', color='tab:green', label=r'Simulated')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Drag Coefficient, $C_D$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CDvsAlpha_comp35k.png')

# %%
# plot CD vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_100), CD_100, 'o--', color='tab:orange', label=r'Experimental')
ax1.plot(alpha_85k, CD_85k, '-', color='tab:purple', label=r'Simulated')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Drag Coefficient, $C_D$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CDvsAlpha_comp85k.png')

# %%
# plot CM vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_40), CM_40, 'bo--', label=r'Experimental')
ax1.plot(alpha_35k, Cm_35k, '-', color='tab:green', label=r'Simulated')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Moment Coefficient, $C_M$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CMvsAlpha_comp35k.png')

# %%
# plot CM vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_100), CM_100, 'o--', color='tab:orange', label=r'Experimental')
ax1.plot(alpha_85k, Cm_85k, '-', color='tab:purple', label=r'Simulated')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Moment Coefficient, $C_M$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CMvsAlpha_comp85k.png')

# %%
# plot Drag Polar
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(CD_40, CL_40, 'bo--', label=r'Experimental')
ax1.plot(CD_35k, CL_35k, '-', color='tab:green', label=r'Simluated')
ax1.set_xlabel( r'Drag Coefficient, $C_D$ [n.d.]',fontsize=14)
ax1.set_ylabel( r'Lift Coefficient, $C_L$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('DragPolar_comp35k.png')

# %%
# plot Drag Polar
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(CD_100, CL_100, 'o--', color='tab:orange', label=r'Experimental')
ax1.plot(CD_85k, CL_85k, '-', color='tab:purple', label=r'Simulated')
ax1.set_xlabel( r'Drag Coefficient, $C_D$ [n.d.]',fontsize=14)
ax1.set_ylabel( r'Lift Coefficient, $C_L$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('DragPolar_comp85k.png')

# %%
q_100

# %%
W = np.linspace(0, 100000, 100)

Cl = W/(q_100[0]*7.85)
alpha = []

for i in range(0, len(Cl)):
  alpha.append(np.degrees(np.interp(Cl[i], CL_100, alpha_100)))

L_D = np.interp(alpha[0], LD_ratio_100, alpha_100)

gamma = np.arctan(L_D)

range = W / np.tan(gamma)


fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(W, range, 'bo--', label=r'Experimental')
# ax1.plot(CD_35k, CL_35k, '-', color='tab:green', label=r'Simluated')
ax1.set_xlabel( r'Weight (Kg)',fontsize=14)
ax1.set_ylabel( r'Range (',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

# %%
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(W, range, 'bo--')
# ax1.plot(CD_35k, CL_35k, '-', color='tab:green', label=r'Simluated')
ax1.set_xlabel( r'Weight (Kg)',fontsize=14)
ax1.set_ylabel( r'Range (Km)',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

# %%
# plot CL vs alpha
fig = plt.figure(figsize=(8,8), tight_layout=True)
ax1 = fig.add_subplot(111)

ax1.plot(np.degrees(alpha_100), CL_100, 'o--', color='tab:orange', label=r'Experimental')
# ax1.plot(alpha_85k, CL_85k, '-', color='tab:purple', label=r'Simulated')
ax1.set_xlabel( r'Angle of Attack, $\alpha$ [deg]',fontsize=14)
ax1.set_ylabel( r'Lift Coefficient, $C_L$ [n.d.]',fontsize=14)
ax1.legend(fontsize=14)
plt.tick_params(labelsize=14)
plt.grid(color='0.95')

plt.savefig('CLvsAlpha_comp85k.png')

# %%
#Question 12
# Expected values
E_al = 10.0E6
E_comp = 1.92E6
v_al = 0.34
v_comp = 0.51

G_al = E_al / (2*(1 + v_al))
G_comp = E_comp / (2*(1 + v_comp))

sigmax_al_bend_123 = (E_al / (1 - v_al**2)) * (ex_al_bend_123 + v_al*ey_al_bend_123) * (1.0E-6)
sigmax_al_bend_456 = (E_al / (1 - v_al**2)) * (ex_al_bend_456 + v_al*ey_al_bend_456) * (1.0E-6)

sigmax_al_torsion_123 = (E_al / (1 - v_al**2)) * (ex_al_torsion_123 + v_al*ey_al_torsion_123) * (1.0E-6)
sigmax_al_torsion_456 = (E_al / (1 - v_al**2)) * (ex_al_torsion_456 + v_al*ey_al_torsion_456) * (1.0E-6)

sigmax_comp_bend_123 = (E_comp / (1 - v_comp**2)) * (ex_comp_bend_123 + v_comp*ey_comp_bend_123) * (1.0E-6)
sigmax_comp_bend_456 = (E_comp / (1 - v_comp**2)) * (ex_comp_bend_456 + v_comp*ey_comp_bend_456) * (1.0E-6)

sigmax_comp_torsion_123 = (E_comp / (1 - v_comp**2)) * (ex_comp_torsion_123 + v_comp*ey_comp_torsion_123) * (1.0E-6)
sigmax_comp_torsion_456 = (E_comp / (1 - v_comp**2)) * (ex_comp_torsion_456 + v_comp*ey_comp_torsion_456) * (1.0E-6)

sigmay_al_bend_123 = (E_al / (1 - v_al**2)) * (ey_al_bend_123 + v_al*ex_al_bend_123) * (1.0E-6)
sigmay_al_bend_456 = (E_al / (1 - v_al**2)) * (ey_al_bend_456 + v_al*ex_al_bend_456) * (1.0E-6)

sigmay_al_torsion_123 = (E_al / (1 - v_al**2)) * (ey_al_torsion_123 + v_al*ex_al_torsion_123) * (1.0E-6)
sigmay_al_torsion_456 = (E_al / (1 - v_al**2)) * (ey_al_torsion_456 + v_al*ex_al_torsion_456) * (1.0E-6)

sigmay_comp_bend_123 = (E_comp / (1 - v_comp**2)) * (ey_comp_bend_123 + v_comp*ex_comp_bend_123) * (1.0E-6)
sigmay_comp_bend_456 = (E_comp / (1 - v_comp**2)) * (ey_comp_bend_456 + v_comp*ex_comp_bend_456) * (1.0E-6)

sigmay_comp_torsion_123 = (E_comp / (1 - v_comp**2)) * (ey_comp_torsion_123 + v_comp*ex_comp_torsion_123) * (1.0E-6)
sigmay_comp_torsion_456 = (E_comp / (1 - v_comp**2)) * (ey_comp_torsion_456 + v_comp*ex_comp_torsion_456) * (1.0E-6)

sigmaxy_al_bend_123 = G_al*gamma_al_bend_123 * (1.0E-6)
sigmaxy_al_bend_456 = G_al*gamma_al_bend_456 * (1.0E-6)

sigmaxy_al_torsion_123 = G_al*gamma_al_torsion_123 * (1.0E-6)
sigmaxy_al_torsion_456 = G_al*gamma_al_torsion_456 * (1.0E-6)

sigmaxy_comp_bend_123 = G_comp*gamma_comp_bend_123 * (1.0E-6)
sigmaxy_comp_bend_456 = G_comp*gamma_comp_bend_456 * (1.0E-6)

sigmaxy_comp_torsion_123 = G_comp*gamma_comp_torsion_123 * (1.0E-6)
sigmaxy_comp_torsion_456 = G_comp*gamma_comp_torsion_456 * (1.0E-6)

print(sigmax_al_torsion_456)
# Out:
# [  0.          -7.40615106 -10.06331976 -14.58616011 -16.33876074
#  -13.34237901 -14.13387607]
